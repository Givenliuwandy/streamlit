# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 31.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.1 MB/s eta 0:00:00

# %%
# %%writefile Sentimenalfagift.py
import streamlit as st
import pandas as pd
import re
import numpy as np
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from tensorflow import keras
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer

st.set_option('deprecation.showPyplotGlobalUse', False)

# Define generate_word_cloud function
def generate_word_cloud(text_data, title=None):
    # Generate word cloud
    wordcloud = WordCloud(width=300, height=200, background_color='white').generate(text_data)

    # Plot word cloud
    plt.figure(figsize=(8, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    if title:
        plt.title(title)
    st.pyplot()

# Define generate_bar_chart function
def generate_bar_chart(text_data, title=None):
    # Tokenize words
    words = nltk.word_tokenize(text_data)

    # Remove stopwords
    stop_words = set(stopwords.words('indonesian'))
    words = [word for word in words if word.lower() not in stop_words]

    # Count word frequencies
    word_freq = Counter(words)

    # Get top 10 words and their frequencies
    top_words = dict(word_freq.most_common(10))

    # Plot bar chart
    plt.figure(figsize=(8, 5))
    plt.bar(top_words.keys(), top_words.values(), color='skyblue')
    plt.xlabel('Words')
    plt.ylabel('Frequency')
    if title:
        plt.title(title)
    plt.xticks(rotation=45)
    plt.tight_layout()
    st.pyplot()

# Title
st.markdown("""
    <h1 style='text-align: center;'>Sentimen Analisis Pengiriman Alfagift</h1>
    """, unsafe_allow_html=True)

# File upload
uploaded_file = st.file_uploader("Upload CSV data", type=["csv"])

if uploaded_file is not None:
    # Read uploaded CSV file
    if uploaded_file.type == 'text/csv':
        df = pd.read_csv(uploaded_file)

        # Rename columns
        df = df.rename(columns={'tbtdr_rating': 'score', 'tbtdr_review': 'content'})
        df = df.drop(columns=['tbtdr_id', 'tbtdr_created_date'])

        # Labeling data based on rating
        label = []
        for row in df['score']:
            if row < 3:
                label.append('negatif')
            elif row == 3:
                label.append('netral')
            elif row > 3:
                label.append('positif')
            else:
                label.append('kosong')
        df['label'] = label

        # Filter out 'netral' and 'kosong' labels
        df = df[df.label != 'netral']
        df = df[df.label != 'kosong']

        # Calculate average length of each review
        avg_length = df['content'].apply(lambda x: len(x.split())).mean()

        # Calculate percentage of positive and negative sentiments
        pos_percentage = (df['label'] == 'positif').mean() * 100
        neg_percentage = (df['label'] == 'negatif').mean() * 100

        st.write("Average length of each review : ", avg_length)

        # Display data processing completion message
        st.write("Data processing completed.")

        # Define stopwords and custom stop words
        nltk.download('wordnet')
        nltk.download('omw-1.4')
        nltk.download('stopwords')

        from nltk.corpus import stopwords
        stop_words = set(stopwords.words('indonesian'))
        custom_stop_words = {'yg', 'nya', 'aja'}
        stop_words.update(custom_stop_words)

        # Function to remove HTML tags, URLs, non-alphanumeric characters, and stopwords
        def remove_tags(string):
            removelist = "yg"
            result = re.sub('<.*?>', '', string)          # Remove HTML tags
            result = re.sub('https://.*', '', result)     # Remove URLs
            result = re.sub(r'[^a-zA-Z'+removelist+']', ' ', result)    # Remove non-alphanumeric characters
            result = result.lower()
            return result

        # Apply stop words removal and stemming to DataFrame column
        df['content'] = df['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
        df['content'] = df['content'].apply(lambda cw: remove_tags(cw))

        # Separate positive and negative sentiment data
        df_pos = df[df['label'] == 'positif']
        df_neg = df[df['label'] == 'negatif']

        # Concatenate all words in positive and negative sentiment data
        words_pos = ' '.join(df_pos['content'])
        words_neg = ' '.join(df_neg['content'])

        # Pie chart and bar chart side by side
        col1, col2 = st.columns(2)

        with col1:
            # Pie chart for sentiment distribution
            st.write("Sentiment Distribution:")
            fig, ax = plt.subplots(figsize=(6, 6))
            labels = ['Positive', 'Negative']
            sizes = [pos_percentage, neg_percentage]
            ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
            ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
            st.pyplot(fig)

        with col2:
            # Bar chart for the number of each score
            st.write("Number of each score:")
            score_counts = df['score'].value_counts().sort_index()
            st.bar_chart(score_counts, width=400)

        # Display word clouds and bar charts for positive and negative sentiments
        if st.button("Generate Word Cloud and Top words"):
            # Word cloud and top 10 words for positive sentiment
            st.write("<h2 style='text-align: center;'>Word Cloud:</h2>", unsafe_allow_html=True)
            col3, col4 = st.columns(2)
            with col3:
                generate_word_cloud(words_pos, 'Word Cloud Positive Sentiment')
            with col4:
                generate_word_cloud(words_neg, 'Word Cloud Negative Sentiment')

            # Word cloud and top 10 words for negative sentiment
            st.write("<h2 style='text-align: center;'>Word Cloud:</h2>", unsafe_allow_html=True)
            col5, col6 = st.columns(2)
            with col5:
                generate_bar_chart(words_pos, 'Top 10 Words Positive Sentiment')
            with col6:
                generate_bar_chart(words_neg, 'Top 10 Words Negative Sentiment')

    # LSTM Model and Input Box
    st.header("Sentiment Prediction with LSTM")
    sentence_input = st.text_input("Enter a sentence:")
    if st.button("Predict Sentiment"):
        # Hyperparameters of the model
        vocab_size = 3000
        oov_tok = ''
        embedding_dim = 100
        max_length = 200
        padding_type='post'
        trunc_type='post'

        # Tokenize sentences
        tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
        tokenizer.fit_on_texts(df['content'])
        word_index = tokenizer.word_index

        # Convert input sentence to sequence and pad sequences
        sequences = tokenizer.texts_to_sequences([sentence_input])
        padded = pad_sequences(sequences, padding=padding_type, truncating=trunc_type, maxlen=max_length)

        # Load the LSTM model
        # Hyperparameters of the model
        vocab_size = 3000
        oov_tok = ''
        embedding_dim = 100
        max_length = 200
        padding_type='post'
        trunc_type='post'

        modellstm = keras.Sequential([
        keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
        keras.layers.Bidirectional(keras.layers.LSTM(64)),
        keras.layers.Dense(24, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
        ])

        # Predict sentiment
        prediction = modellstm.predict(padded)

        # Output the sentiment prediction
        if prediction >= 0.5:
            st.write("Predicted sentiment: Positive😁👍")
        else:
            st.write("Predicted sentiment: Negative😭👎")
# Out:
# Writing Sentimenalfagift.py

# %%
! wget -q -O - https://loca.lt/mytunnelpassword
# Out:
# 34.75.218.8

# %%
! streamlit run Sentimenalfagift.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.75.218.8:8501
#
# npx: installed 22 in 6.308s
# your url is: https://ninety-clowns-learn.loca.lt
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:13:08.847
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:13:36.781
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:15:40.524
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# 2024-04-28 15:16:09.418
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# 2024-04-28 15:16:30.833
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# 2024-04-28 15:16:55.077
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:17:01.956
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:20:11.158
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:20:16.684
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:25:38.221
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:26:41.311
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:28:40.662
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:29:05.988
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:32:16.497
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:32:26.449
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:32:27.820 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Sentimenalfagift.py", line 126, in <module>
#     generate_word_cloud(words_pos, 'Word Cloud Positive Sentiment')
#   File "/content/Sentimenalfagift.py", line 28, in generate_word_cloud
#     words = nltk.word_tokenize(text_data)
#   File "/usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py", line 129, in word_tokenize
#     sentences = [text] if preserve_line else sent_tokenize(text, language)
#   File "/usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py", line 106, in sent_tokenize
#     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#   File "/usr/local/lib/python3.10/dist-packages/nltk/data.py", line 750, in load
#     opened_resource = _open(resource_url)
#   File "/usr/local/lib/python3.10/dist-packages/nltk/data.py", line 876, in _open
#     return find(path_, path + [""]).open()
#   File "/usr/local/lib/python3.10/dist-packages/nltk/data.py", line 583, in find
#     raise LookupError(resource_not_found)
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
#
# 2024-04-28 15:33:23.511
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:33:33.541
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:33:37.346
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:37:34.093
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:37:44.032
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:41:07.693
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:41:14.891
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 15:41:15.542 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Sentimenalfagift.py", line 141, in <module>
#     generate_bar_chart(words_pos, 'Top 10 Words - Positive Sentiment')
#   File "/content/Sentimenalfagift.py", line 17, in generate_bar_chart
#     words = nltk.word_tokenize(text_data)
#   File "/usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py", line 129, in word_tokenize
#     sentences = [text] if preserve_line else sent_tokenize(text, language)
#   File "/usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py", line 106, in sent_tokenize
#     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#   File "/usr/local/lib/python3.10/dist-packages/nltk/data.py", line 750, in load
#     opened_resource = _open(resource_url)
#   File "/usr/local/lib/python3.10/dist-packages/nltk/data.py", line 876, in _open
#     return find(path_, path + [""]).open()
#   File "/usr/local/lib/python3.10/dist-packages/nltk/data.py", line 583, in find
#     raise LookupError(resource_not_found)
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
#
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 2024-04-28 15:42:50.473
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:42:54.295
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:45:22.507
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:45:28.813
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:45:39.033
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:48:41.432
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:48:48.768
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:48:58.533
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:49:07.330
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:51:22.435
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:51:28.560
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:54:41.702
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:54:48.524
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:57:12.370
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 15:57:16.754
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 16:00:15.896
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 16:00:19.948
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 16:37:44.954
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 16:48:37.683
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 16:58:31.768904: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 16:58:31.769018: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 16:58:31.772309: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-28 16:58:31.788950: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-28 16:58:33.471359: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-28 16:58:35.502
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 16:58:40.388
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 16:58:42.027 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Sentimenalfagift.py", line 161, in <module>
#     generate_word_chart(words_pos, 'Top 10 Words Positive Sentiment')
# NameError: name 'generate_word_chart' is not defined
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 16:59:53.729
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 16:59:55.331 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Sentimenalfagift.py", line 161, in <module>
#     generate_word_chart(words_pos, 'Top 10 Words Positive Sentiment')
# NameError: name 'generate_word_chart' is not defined
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:03:03.868
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:03:07.303
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:03:27.323
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:03:32.464
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 17:03:33.863 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Sentimenalfagift.py", line 193, in <module>
#     modellstm = keras.models.load_model("modellstm.h5")  # Path to your saved model
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py", line 262, in load_model
#     return legacy_sm_saving_lib.load_model(
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/saving/legacy/save.py", line 234, in load_model
#     raise IOError(
# OSError: No file or directory found at modellstm.h5
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:05:56.285
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:06:03.409
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-28 17:06:04.391 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Sentimenalfagift.py", line 202, in <module>
#     tokenizer.fit_on_texts(train_sentences)
# NameError: name 'train_sentences' is not defined
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:07:20.981
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:07:28.626
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:08:29.016
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:08:43.794
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:08:44.018
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 870ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:09:19.784
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:09:20.024
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 915ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:09:35.189
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:09:35.409
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# ...
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:13:36.550
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:13:46.721
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:13:46.951
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 868ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:14:20.605
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 857ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:14:25.356
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:15:34.633
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 848ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:15:49.746
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:15:49.973
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 914ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:16:05.492
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:16:05.731
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 918ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:16:29.795
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:16:30.077
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 881ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:16:43.767
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 915ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:16:48.883
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:17:00.274
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:17:17.735
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:17:17.957
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 931ms/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:17:24.197
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:17:47.637
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-04-28 17:17:47.884
# ════════════════════════════════════════════════
# deprecation.showPyplotGlobalUse IS NO LONGER SUPPORTED.
#
# The support for global pyplot instances is planned to be removed soon.
#
# Please update <user defined>.
# ════════════════════════════════════════════════
#
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1/1 [==============================] - 1s 1s/step

# %%
# %%writefile requirement.txt
# streamlit
# Keras-Preprocessing
# sastrawi
# nltk
# Out:
# Writing requirement.txt

# %%
pip install -r '/content/requirement.txt'
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (from -r /content/requirement.txt (line 1)) (1.33.0)
# Collecting Keras-Preprocessing (from -r /content/requirement.txt (line 2))
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.4 MB/s eta 0:00:00
# Collecting sastrawi (from -r /content/requirement.txt (line 3))
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r /content/requirement.txt (line 4)) (3.8.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (1.25.2)
# Requirement already satisfied: packaging<25,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (0.9.0b1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/requirement.txt (line 1)) (4.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing->-r /content/requirement.txt (line 2)) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->-r /content/requirement.txt (line 4)) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->-r /content/requirement.txt (line 4)) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->-r /content/requirement.txt (line 4)) (4.66.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r /content/requirement.txt (line 1)) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit->-r /content/requirement.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit->-r /content/requirement.txt (line 1)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit->-r /content/requirement.txt (line 1)) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit->-r /content/requirement.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit->-r /content/requirement.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit->-r /content/requirement.txt (line 1)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit->-r /content/requirement.txt (line 1)) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->-r /content/requirement.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->-r /content/requirement.txt (line 1)) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r /content/requirement.txt (line 1)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/requirement.txt (line 1)) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r /content/requirement.txt (line 1)) (0.1.2)
# Installing collected packages: sastrawi, Keras-Preprocessing
# Successfully installed Keras-Preprocessing-1.1.2 sastrawi-1.0.1
